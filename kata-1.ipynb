# %% [markdown]
# # Tu primer programa

# %%
from datetime import date
print("today´s date is: ",(date.today()))
# Out:
# today´s date is:  2022-02-08

# %% [markdown]
# # Construir un conveertidor de unidades

# %%
parsec = 11
lightyear = 3.26156 
conversion = parsec*lightyear
print((parsec), "parsec es ", (conversion),"lightyears")
# Out:
# 11 parsec es  35.877159999999996 lightyears
