# %%
asteroide=49
if asteroide>25:
    print("advertencia asteroide serca")
else:
    print("no hay peligro siga con su dia")

# %%
asteroide=19
if asteroide>=20:
    print("asteroide en el cielo")
else:
    print("nada que ver")

# %%
velocidad=27
tamaño=44
if tamaño>25 and tamaño<100:
    print("el meteorito causara mucho daño")
elif velocidad >25:
    print("advertencia asteroide peligroso")
elif velocidad >=20:
    print("rayo de luz en el cielo")
else:
    print("nada que ver")
